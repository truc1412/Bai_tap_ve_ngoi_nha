# %%
import turtle as t
pen=t.Turtle()

t.bgcolor("cyan")
pen.speed(200)
pen.fillcolor ("blue")

pen.penup()
pen.goto(-300,-200)
pen.pendown()
pen.begin_fill()
pen.forward(125)
pen.left(90)
pen.forward(150)
pen.left(90)
pen.forward(125)
pen.left(90)
pen.forward(150)
pen.left(90)
pen.forward(125)
pen.left(30)
pen.end_fill()

pen.fillcolor ("yellow")
pen.begin_fill()
pen.forward(100)
pen.left(60)
pen.forward(150)
pen.left(120)
pen.forward(100)
pen.end_fill()
pen.right(30)
pen.right(60)

pen.fillcolor ("red")
pen.begin_fill()
pen.forward(125)
pen.left(120)
pen.forward(125)
pen.left(120)
pen.forward(125)
pen.left(30)
pen.end_fill()

pen.fillcolor ("orange")
pen.begin_fill()
pen.forward(100)
pen.left(90)
pen.forward(125)
pen.left(90)
pen.forward(100)
pen.left(150)
pen.end_fill()

pen.fillcolor ("green")
pen.begin_fill()
pen.penup()
pen.goto(-260,-200)
pen.pendown()
pen.forward(50)
pen.left(90)
pen.forward(50)
pen.left(90)
pen.forward(50)
pen.left(90)
pen.forward(50)
pen.left(90)
pen.end_fill()

pen.fillcolor ("brown")
pen.begin_fill()
pen.penup()
pen.goto(-150,-125)
pen.pendown()
pen.left(30)
pen.forward(45)
pen.left(60)
pen.forward(55)
pen.left(120)
pen.forward(45)
pen.left(60)
pen.forward(55)
pen.end_fill()

pen.fillcolor ("yellow")
pen.penup()
pen.goto(100,150)
pen.pendown()
pen.begin_fill()
pen.circle(50)
pen.end_fill()

pen.right(90)
pen.forward(50)
pen.penup()
pen.goto(200,150)
pen.pendown()
pen.backward(50)
pen.penup()
pen.goto(150,100)
pen.pendown()
pen.right(90)
pen.backward(50)
pen.penup()
pen.goto(150,200)
pen.pendown()
pen.forward(50)
pen.penup()
pen.goto(115,185)
pen.pendown()
pen.left(45)
pen.forward(25)
pen.penup()
pen.backward(125)
pen.pendown()
pen.backward(25)
pen.penup()
pen.goto(115,115)
pen.pendown()
pen.right(90)
pen.backward(25)
pen.penup()
pen.forward(125)
pen.pendown()
pen.forward(25)
pen.right(45)

pen.fillcolor ("brown")
pen.begin_fill()
pen.penup()
pen.goto(100,-250)
pen.pendown()
pen.forward(25)
pen.left(90)
pen.forward(50)
pen.left(90)
pen.forward(25)
pen.left(90)
pen.forward(50)
pen.end_fill()

pen.fillcolor ("green")
pen.begin_fill()
pen.penup()
pen.goto(70,-200)
pen.left(90)
pen.pendown()
pen.forward(85)
pen.left(120)
pen.forward(85)
pen.left(120)
pen.forward(85)
pen.left(120)
pen.end_fill()

pen.fillcolor ("green")
pen.begin_fill()
pen.penup()
pen.goto(70,-125)
pen.pendown()
pen.forward(85)
pen.left(120)
pen.forward(85)
pen.left(120)
pen.forward(85)
pen.left(120)
pen.end_fill()

pen.fillcolor ("green")
pen.begin_fill()
pen.penup()
pen.goto(70,-50)
pen.pendown()
pen.forward(85)
pen.left(120)
pen.forward(85)
pen.left(120)
pen.forward(85)
pen.left(120)
pen.end_fill()

pen.penup()
pen.goto(-200,-250)
pen.pendown()
t.done()
